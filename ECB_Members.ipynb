# %%
import pandas as pd

# %%
# Define the CSV content
csv_data = """Country,Name,Role
France,Christine Lagarde,President
Spain,Luis de Guindos,Vice President
Italy,Piero Cipollone,Member of the Executive Board
Republic of Ireland,Philip R. Lane,Member of the Executive Board & Chief Economist
Netherlands,Frank Elderson,Member of the Executive Board; Vice-chair of the Supervisory board
Germany,Isabel Schnabel,Member of the Executive Board
Spain,Pablo Hernández de Cos,
Germany,Joachim Nagel,
Belgium,Pierre Wunsch,
Greece,Yannis Stournaras,
Croatia,Boris Vujčić,
Luxembourg,Gaston Reinesch,
France,François Villeroy de Galhau,
Austria,Robert Holzmann,
Slovakia,Peter Kažimír,
Lithuania,Gediminas Šimkus,
Finland,Olli Rehn,
Portugal,Mario Centeno,
Malta,Edward Scicluna,
Slovenia,Boštjan Vasle,
Estonia,Madis Müller,
Latvia,Mārtiņš Kazāks,
Netherlands,Klaas Knot,
Cyprus,Constantinos Herodotou,
Republic of Ireland,Gabriel Makhlouf,
Italy,Fabio Panetta"""

# Save the CSV content to a file
with open('ecb_governing_council.csv', 'w') as file:
    file.write(csv_data)

# Read the CSV file into a DataFrame
ECB_df = pd.read_csv('ecb_governing_council.csv')

# Create a new column called "Position" based on the "Role" column
ECB_df['Position'] = ECB_df['Role'].apply(
    lambda x: 'Executive Board' if pd.notnull(x) else 'National Governor'
)

# Rename the 'Name' column to 'Full Name'
ECB_df.rename(columns={'Name': 'Full Name'}, inplace=True)

ECB_df.rename(columns={'Role': 'Executive Role'}, inplace=True)

# Split the "Full Name" column into two separate columns: "First Name" and "Surname"
ECB_df[['First Name', 'Surname']] = ECB_df['Full Name'].str.split(' ', n=1, expand=True)

desired_order = ['Full Name', 'First Name', 'Surname', 'Country', 'Position', 'Executive Role']

ECB_df = ECB_df[desired_order]

# Display the DataFrame to verify the data is correctly loaded
ECB_df
# Out:
#                       Full Name    First Name             Surname  \
# 0             Christine Lagarde     Christine             Lagarde
# 1               Luis de Guindos          Luis          de Guindos
# 2               Piero Cipollone         Piero           Cipollone
# 3                Philip R. Lane        Philip             R. Lane
# 4                Frank Elderson         Frank            Elderson
# 5               Isabel Schnabel        Isabel            Schnabel
# 6        Pablo Hernández de Cos         Pablo    Hernández de Cos
# 7                 Joachim Nagel       Joachim               Nagel
# 8                 Pierre Wunsch        Pierre              Wunsch
# 9             Yannis Stournaras        Yannis          Stournaras
# 10                 Boris Vujčić         Boris              Vujčić
# 11              Gaston Reinesch        Gaston            Reinesch
# 12  François Villeroy de Galhau      François  Villeroy de Galhau
# 13              Robert Holzmann        Robert            Holzmann
# 14                Peter Kažimír         Peter             Kažimír
# 15             Gediminas Šimkus     Gediminas              Šimkus
# 16                    Olli Rehn          Olli                Rehn
# 17                Mario Centeno         Mario             Centeno
# 18              Edward Scicluna        Edward            Scicluna
# 19                Boštjan Vasle       Boštjan               Vasle
# 20                 Madis Müller         Madis              Müller
# 21               Mārtiņš Kazāks       Mārtiņš              Kazāks
# 22                   Klaas Knot         Klaas                Knot
# 23       Constantinos Herodotou  Constantinos           Herodotou
# 24             Gabriel Makhlouf       Gabriel            Makhlouf
# 25                Fabio Panetta         Fabio             Panetta
#
#                 Country           Position  \
# 0                France    Executive Board
# 1                 Spain    Executive Board
# 2                 Italy    Executive Board
# 3   Republic of Ireland    Executive Board
# 4           Netherlands    Executive Board
# 5               Germany    Executive Board
# 6                 Spain  National Governor
# 7               Germany  National Governor
# 8               Belgium  National Governor
# 9                Greece  National Governor
# 10              Croatia  National Governor
# 11           Luxembourg  National Governor
# 12               France  National Governor
# 13              Austria  National Governor
# 14             Slovakia  National Governor
# 15            Lithuania  National Governor
# 16              Finland  National Governor
# 17             Portugal  National Governor
# 18                Malta  National Governor
# 19             Slovenia  National Governor
# 20              Estonia  National Governor
# 21               Latvia  National Governor
# 22          Netherlands  National Governor
# 23               Cyprus  National Governor
# 24  Republic of Ireland  National Governor
# 25                Italy  National Governor
#
#                                        Executive Role
# 0                                           President
# 1                                      Vice President
# 2                       Member of the Executive Board
# 3     Member of the Executive Board & Chief Economist
# 4   Member of the Executive Board; Vice-chair of t...
# 5                       Member of the Executive Board
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
